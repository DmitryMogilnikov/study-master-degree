# %% [markdown]
# ## Задание 1.1 (5 баллов)
#
# Какие недостатки вы видите в данной реализации? Реализуйте поддержку (полностью самостоятельно или модифицируя приведенный код):
# - [унарных операций](https://docs.python.org/3/reference/datamodel.html#object.__neg__)
# - деления
# - возведения в степень
#
# Каким образом можно проверить корректность решения?  Реализуйте достаточный, по вашему мнению, набор тестов.

# %%
from dataclasses import dataclass
from typing import Union, Callable
from numbers import Number
from math import cos, sin, exp, log

@dataclass
class Dual:
    real: float
    dual: float = 0.0

    def __add__(self, other: Union["Dual", Number]) -> "Dual":
         match other:
            case Dual():
                return Dual(self.real + other.real, self.dual + other.dual)
            case Number():
                return Dual(float(other) + self.real, self.dual)

    def __mul__(self, other: Union["Dual", Number]) -> "Dual":
         match other:
            case Dual():
                return Dual(self.real * other.real, self.real * other.dual + self.dual * other.real)
            case Number():
                return Dual(float(other) * self.real, float(other) * self.dual)  
    
    def __neg__(self) -> "Dual":
        return Dual(-self.real, -self.dual)
    
    def __pos__(self) -> "Dual":
        return Dual(+self.real, +self.dual)
    
    def __abs__(self) -> "Dual":
        return Dual(abs(self.real), abs(self.dual))

    def __sub__(self, other: Union["Dual", Number]) -> "Dual":
        match other:
            case Dual():
                return Dual(self.real - other.real, self.dual - other.dual)
            case Number():
                return Dual(float(other) - self.real, self.dual)
    
    def __truediv__(self, other: Union["Dual", Number]) -> "Dual":
        if other.real == 0:
            raise ZeroDivisionError("Attepting to divide by zero")
        
        if isinstance(other, Dual):
            other = other
        else: 
            other = Dual(real=other)
        
        real = self.real / other.real
        dual = (self.dual * other.real - self.real * other.dual)/ (other.real * other.real)
        
        return Dual(real, dual)
    
    def __rtruediv__(self, other: float) -> "Dual":
        if self.real == 0:
            raise ZeroDivisionError("Attempting to divide by a zero")
            
        return Dual(real=other) / self

    def __pow__(self, power: Union["Dual", Number]) -> "Dual": 
        if isinstance(power, Dual):
            other = power
            real = self.real ** other.real
            dual = real * ((self.dual / self.real) * other.real + log(self.real) * other.dual)
            return Dual(real, dual) 
        
        real = self.real ** power
        dual = real * (self.dual / self.real) * power
        return Dual(real, dual)
    
    def __rpow__(self, other: Union["Dual", Number]) -> "Dual":        
        if other.real == 0:
            raise Exception("log(0) is not defined")

        return Dual(other) ** self

    __radd__ = __add__
    __rmul__ = __mul__  
    __rsub__ = __sub__
    

def diff(func: Callable[[float], float]) -> Callable[[float], float]:
    return lambda x: func(Dual(x, 1.0)).dual

# %%
import pytest

#Реализуем проверку каждого отдельного метода с использованием assert
# Проверка унарных операций __neg__, __pos__, __abs__. Без реализации этих методов в классе будет возникать TypeError: bad operand type for unary (+, -, abs()): 'Dual'
# __neg__:
f = lambda x: -x 
f_diff = diff(f)
assert f_diff(2) == -1, "__neg__ is not right"

# __pos__:
f = lambda x: +x 
f_diff = diff(f)
assert f_diff(2) == 1, "__pos__ is not right"

# __abs__:
f = lambda x: abs(-x)
f_diff = diff(f)
assert f_diff(2) == 1, "__abs__ is not right"

#Проверим поддержку операции вычитания __sub__:
# Функция, которую будем дифференцировать
def f(x: float) -> float:
    return 5 * x * x - 2 * x - 2

f_diff = diff(f)
assert f_diff(2) == 18, "__sub__ is not right"

#Проверим поддержку операции деления __truediv__:
#1. Проверка деления на ноль
def f(x: float) -> float:
    return x / 0

f_diff = diff(f)

def test_zero_division():
    with pytest.raises(ZeroDivisionError):
        f_diff(2)

#2.
def f(x: float) -> float:
    return 5 / (x * x) - x * x / 2 - 2

f_diff = diff(f)
assert f_diff(2) == -3.25, "__truediv__ is not right"

#Проверим операцию возведения в степень __pow__:
#1
f = lambda x: x ** 4 
f_diff = diff(f)
assert f_diff(2) == 32, "__pow__ is not right"

#2
f = lambda x: 4 ** x
f_diff = diff(f)
assert round(f_diff(2), 4) == 22.1807, "__pow__ is not right"

#3
f = lambda x: x ** x
f_diff = diff(f)
assert round(f_diff(2), 5) == 6.77259, "__pow__ is not right"

#4
f = lambda x: 0 ** x
f_diff = diff(f)
def test_negative_base():
    with pytest.raises(AssertionError):
        f_diff(2)

#5
f = lambda x: x ** 5
f_diff = diff(f)
def test_negative_base():
    with pytest.raises(ZeroDivisionError):
        f_diff(0)

#Проверим компиляцию всех операций:
# Функция, которую будем дифференцировать
def f(x: float) -> float:
    return 5 * x * x / (x ** 4 + 2) - 2 * x - 2

f_diff = diff(f)
f_diff(2)
assert round(f_diff(2), 4) == -2.8642, "wrong answer"

# %% [markdown]
# ## Задание 1.2 (7 баллов)
# Придумайте способ и реализуйте поддержку функций:
# - `exp()`
# - `cos()`
# - `sin()`
# - `log()`
#
# Добавьте соответствующие тесты

# %%
def sin_d(dual_num) -> "Dual":
    match dual_num:
        case Dual():
            real = sin(dual_num.real)
            dual = cos(dual_num.real) * dual_num.dual
            return Dual(real, dual)
        case Number():
            return Dual(sin(dual_num.real))

def cos_d(dual_num) -> "Dual":
    match dual_num:
        case Dual():
                real = cos(dual_num.real)
                dual = -sin(dual_num.real) * dual_num.dual
                return Dual(real, dual)
        case Number():
            return Dual(cos(dual_num.real))

def exp_d(dual_num) -> "Dual":
    match dual_num:
        case Dual():
            real = exp(dual_num.real)
            dual = real * dual_num.dual
            return Dual(real, dual)
        case Number():
            return Dual(exp(dual_num.real))

def log_d(dual_num) -> "Dual":
    if dual_num.real == 0:
        raise AssertionError(f"log(0) is not defined")

    match dual_num:
        case Dual():
            real = log(dual_num.real)
            dual = dual_num.dual / dual_num.real
            return Dual(real, dual)
        case Number():
            return Dual(log(dual_num.real))

# %%
from math import pi, exp

#Реализуем проверку каждого отдельного метода с использованием assert
def test_sin():
    f = lambda x: sin_d(x ** 2)
    f_diff = diff(f)
    assert f_diff(pi) == 2 * pi * cos(pi**2), "sin() is not right"

def test_cos():
    f = lambda x: cos_d(x ** 2)
    f_diff = diff(f)
    assert f_diff(pi) == -2 * pi * sin(pi**2), "cos() is not right"

def test_exp():
    f = lambda x: exp_d(x ** 2)
    f_diff = diff(f)
    assert f_diff(pi) == 2 * pi * exp(pow(pi, 2)), "exp() is not right"

def test_log():
    f = lambda x: log_d(x ** 2)
    f_diff = diff(f)
    assert f_diff(pi) == 2 / pi, "log() is not right"

    f = lambda x: log_d(x)
    f_diff =diff(f)
    with pytest.raises(AssertionError):
        f_diff(0)

# %%
test_sin()
test_cos()
test_exp()
test_log()

# %% [markdown]
# ## Задание 1.3 (3 балла)
#
# Воспользуйтесь методами **численного** дифференцирования для "проверки" работы кода на нескольких примерах. Например,  библиотеке `scipy` есть функция `derivative`. Или реализуйте какой-нибудь метод численного дифференцирования самостоятельно (**+5 баллов**)

# %%
from scipy.misc import derivative

def f(x: float) -> float:
    return (x**3) - 2 * (x**2) * (x**2 + 2) + (x**3 + x + 5)

print(diff(f)(2))
print(derivative(f, 2.))
print('Right answer is -55')
# Out:
# -55.0
# -69.0
# Right answer is -55

# %%
def f(x: float) -> float:
    return 81 * x / (x + (x**2))

print(diff(f)(2))
print(derivative(f, 2.))

print('Right answer is -9')
# Out:
# -9.0
# -10.125
# Right answer is -9

# %%
def f(x: float) -> float:
    return sin_d(x)/(cos_d(x)+(x**2))

print(diff(f)(2))

def f(x: float) -> float:
    return sin(x)/(cos(x)+(x**2))

print(derivative(f, 2.))

print('Right answer is -0.334925')
# Out:
# -0.3349249363278422
# -0.2643422639065857
# Right answer is -0.334925

# %% [markdown]
# ## Задание 1.4 (10 баллов)
#
# Необходимо разработать систему автоматического тестирования алгоритма дифференцирования в следующем виде:
# - реализовать механизм генерации "случайных функций" (например, что-то вроде такого: $f(x) = x + 5 * x - \cos(20 * \log(12 - 20 * x * x )) - 20 * x$ )
# - сгенерировать достаточно большое число функций и сравнить результаты символьного и численного дифференцирования в случайных точках

# %%
from dataclasses import dataclass
from random import randint
from math import sin, cos, exp, log

@dataclass
class FunctionGenerator:

    def generate_tree(self, level: int = 0) -> str:
        result = ""
        
        choice = randint(0, 3)
        if level < 2:
            choice = randint(2, 3)
        elif level % 2 == 0:
            choise = 0
        
        match choice:
            case 0:
                result += self.generate_var()
            case 1:
                result += self.generate_const()
            case 2:
                result += self.generate_unary(level + 1)
            case 3:
                result += self.generate_binary(level + 1)
        
        return result

    def generate_var(self) -> str: 
        return 'x'
        
    def generate_const(self) -> str:
        return str(randint(0, 20))

    def generate_unary(self, level: int) -> str:
        un_op = randint(0, 3)
        subexpr = self.generate_tree(level)
        match un_op:
            case 0:
                return f"cos({subexpr})"
            case 1:
                return f"sin({subexpr})"
            case 2:
                return f"exp({subexpr})"
            case 3:
                return f"log({subexpr})"

    def generate_binary(self, level: int)-> str:
        bin_op = randint(0, 4)
        sub1 = self.generate_tree(level)
        sub2 = self.generate_tree(level)
        match bin_op:
            case 0:
                return f"{sub1} + {sub2}"
            case 1:
                return f"{sub1} - {sub2}"
            case 2:
                return f"{sub1} / {sub2}"
            case 3:
                return f"{sub1} * {sub2}"
            case 4:
                return f"{sub1} ** {sub2}"

# %%
gen = FunctionGenerator()

# %%
for i in range(100):
    point = randint(2, 10)

    try:
        tree = gen.generate_tree()
        func = eval(f"lambda x: {tree}")

        tree_d = tree.replace("sin", "sin_d").replace("cos", "cos_d").replace("log", "log_d").replace("exp", "exp_d")
        func_d = eval(f"lambda x: {tree_d}")

        num_diff = derivative(func, point)
        dual_diff = diff(func_d)(point)

        print(f'Функция для дифференцирования, в точке x = {point}: \n{tree}')
        print(f"Методом численного дифференцирования: {num_diff:0.5f}")
        print(f"Методом автоматического дифференцирования: {dual_diff:0.5f}")
        print("")
    except:
        next
# Out:
# Функция для дифференцирования, в точке x = 9:
# sin(cos(log(x) + 16))
# Методом численного дифференцирования: 0.04812
# Методом автоматического дифференцирования: 0.04725
#
# Функция для дифференцирования, в точке x = 6:
# cos(cos(x))
# Методом численного дифференцирования: -0.11551
# Методом автоматического дифференцирования: -0.22892
#
# Функция для дифференцирования, в точке x = 6:
# sin(14 ** 7)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 5:
# cos(3 - log(log(x * sin(x * 0) + x) / exp(exp(log(3 + x) - 1 * sin(14)))))
# Методом численного дифференцирования: 0.16708
# Методом автоматического дифференцирования: -0.17521
#
# Функция для дифференцирования, в точке x = 2:
# log(cos(20) * x / exp(x))
# Методом численного дифференцирования: -0.45069
# Методом автоматического дифференцирования: -0.50000
#
# Функция для дифференцирования, в точке x = 8:
# sin(x + 16)
# Методом численного дифференцирования: 0.35693
# Методом автоматического дифференцирования: 0.42418
#
# Функция для дифференцирования, в точке x = 7:
# x ** x / sin(cos(log(x))) / cos(cos(sin(x) * 8) - sin(cos(13)) + x + 6)
# Методом численного дифференцирования: -21774015.57902
# Методом автоматического дифференцирования: -8414518.55917
#
# Функция для дифференцирования, в точке x = 6:
# sin(x / x * x + exp(x))
# Методом численного дифференцирования: -0.65260
# Методом автоматического дифференцирования: 211.06137
#
# Функция для дифференцирования, в точке x = 7:
# sin(exp(x)) ** 8 + 18 + 8
# Методом численного дифференцирования: -0.37524
# Методом автоматического дифференцирования: 0.18560
#
# Функция для дифференцирования, в точке x = 2:
# exp(cos(x))
# Методом численного дифференцирования: -0.67247
# Методом автоматического дифференцирования: -0.59976
#
# Функция для дифференцирования, в точке x = 8:
# log(x / x)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 5:
# exp(3 ** 1)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 8:
# x / exp(6) + log(16) ** 8 ** 0 + cos(x / 15) + 12 / x / sin(cos(x))
# Методом численного дифференцирования: -2.12730
# Методом автоматического дифференцирования: 71.11273
#
# Функция для дифференцирования, в точке x = 10:
# exp(cos(x))
# Методом численного дифференцирования: 0.30118
# Методом автоматического дифференцирования: 0.23508
#
# Функция для дифференцирования, в точке x = 7:
# cos(18) * cos(x)
# Методом численного дифференцирования: -0.36505
# Методом автоматического дифференцирования: -0.43382
#
# Функция для дифференцирования, в точке x = 10:
# 6 ** 17 - exp(17)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 5:
# sin(x - 16) - 5 - log(5) * 7
# Методом численного дифференцирования: 0.00372
# Методом автоматического дифференцирования: 0.00443
#
# Функция для дифференцирования, в точке x = 8:
# x + 8 ** cos(17)
# Методом численного дифференцирования: 1.00000
# Методом автоматического дифференцирования: 1.00000
#
# Функция для дифференцирования, в точке x = 8:
# sin(log(6) ** x)
# Методом численного дифференцирования: 0.28584
# Методом автоматического дифференцирования: 51.59934
#
# Функция для дифференцирования, в точке x = 2:
# x ** x + exp(2)
# Методом численного дифференцирования: 13.00000
# Методом автоматического дифференцирования: 6.77259
#
# Функция для дифференцирования, в точке x = 10:
# log(log(x * x))
# Методом численного дифференцирования: 0.04370
# Методом автоматического дифференцирования: 0.04343
#
# Функция для дифференцирования, в точке x = 10:
# sin(x) - sin(7)
# Методом численного дифференцирования: -0.70605
# Методом автоматического дифференцирования: -0.83907
#
# Функция для дифференцирования, в точке x = 9:
# x + x ** x - exp(11 * 19 + 18)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 1238670310.19442
#
# Функция для дифференцирования, в точке x = 9:
# cos(log(x))
# Методом численного дифференцирования: -0.09060
# Методом автоматического дифференцирования: -0.09001
#
# Функция для дифференцирования, в точке x = 7:
# 5 * exp(2) * 15 ** 15 + cos(5 ** cos(x) / x) * 17
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 4.53497
#
# Функция для дифференцирования, в точке x = 2:
# x + log(x + 11) + x ** x * 14 + 7 / 4 + 4 * 19
# Методом численного дифференцирования: 183.07708
# Методом автоматического дифференцирования: 95.89317
#
# Функция для дифференцирования, в точке x = 4:
# log(sin(9))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 10:
# x + 10 / cos(x)
# Методом численного дифференцирования: 1136.25299
# Методом автоматического дифференцирования: -6.72712
#
# Функция для дифференцирования, в точке x = 6:
# cos(log(3 + cos(x - x ** 18 - x)))
# Методом численного дифференцирования: -0.22645
# Методом автоматического дифференцирования: 47748638210374.92188
#
# Функция для дифференцирования, в точке x = 5:
# log(exp(7 / x))
# Методом численного дифференцирования: -0.29167
# Методом автоматического дифференцирования: -0.28000
#
# Функция для дифференцирования, в точке x = 4:
# sin(sin(x + x / x))
# Методом численного дифференцирования: 0.20540
# Методом автоматического дифференцирования: 0.16294
#
# Функция для дифференцирования, в точке x = 5:
# exp(x - log(log(log(x)) / 17) * exp(cos(x - x)) * log(6 - 1))
# Методом численного дифференцирования: -365749637.90965
# Методом автоматического дифференцирования: -131526467.52809
#
# Функция для дифференцирования, в точке x = 3:
# cos(cos(11 - x)) / exp(11 - 6)
# Методом численного дифференцирования: 0.00039
# Методом автоматического дифференцирования: -0.00097
#
# Функция для дифференцирования, в точке x = 6:
# cos(sin(x))
# Методом численного дифференцирования: 0.10872
# Методом автоматического дифференцирования: 0.26481
#
# Функция для дифференцирования, в точке x = 4:
# sin(log(sin(1 / x)))
# Методом численного дифференцирования: -0.05005
# Методом автоматического дифференцирования: -0.04239
#
# Функция для дифференцирования, в точке x = 4:
# cos(log(14))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: -0.00000
#
# Функция для дифференцирования, в точке x = 7:
# log(sin(cos(sin(17))))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 10:
# log(log(x + x))
# Методом численного дифференцирования: 0.03356
# Методом автоматического дифференцирования: 0.03338
#
# Функция для дифференцирования, в точке x = 4:
# log(3) ** log(x)
# Методом численного дифференцирования: 0.02729
# Методом автоматического дифференцирования: 0.02679
#
# Функция для дифференцирования, в точке x = 6:
# log(4 + 2)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 8:
# 19 ** cos(cos(cos(x - x + 12))) * log(x * x)
# Методом численного дифференцирования: 2.55161
# Методом автоматического дифференцирования: 2.53827
#
# Функция для дифференцирования, в точке x = 9:
# sin(exp(8 / 4))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 6:
# cos(cos(15))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 6:
# sin(x * sin(15) ** 13)
# Методом численного дифференцирования: 0.00372
# Методом автоматического дифференцирования: 0.00372
#
# Функция для дифференцирования, в точке x = 8:
# sin(20 * 0)
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 8:
# exp(x * x + log(cos(log(x) - log(9)) * 5) ** 8)
# Методом численного дифференцирования: 2680619696373230811409127446913249916932154139948875776.00000
# Методом автоматического дифференцирования: 921016399535000293524445432709292914032569745408.00000
#
# Функция для дифференцирования, в точке x = 8:
# cos(x ** 10)
# Методом численного дифференцирования: 0.21574
# Методом автоматического дифференцирования: 828561488.61865
#
# Функция для дифференцирования, в точке x = 9:
# exp(sin(x))
# Методом численного дифференцирования: -1.05455
# Методом автоматического дифференцирования: -1.37582
#
# Функция для дифференцирования, в точке x = 10:
# exp(x) ** x + 8 + 9 ** 4 * exp(cos(x * 9)) + cos(sin(x))
# Методом численного дифференцирования: 17725655913805826839172225061234963413315094828810240.00000
# Методом автоматического дифференцирования: 537623428363227418990677437210524046883553280.00000
#
# Функция для дифференцирования, в точке x = 6:
# sin(exp(x))
# Методом численного дифференцирования: 0.23604
# Методом автоматического дифференцирования: 105.99751
#
# Функция для дифференцирования, в точке x = 4:
# 8 + x - 9 * sin(sin(cos(sin(0 * 6))) ** 18)
# Методом численного дифференцирования: 1.00000
# Методом автоматического дифференцирования: 1.00000
#
# Функция для дифференцирования, в точке x = 8:
# sin(exp(x + sin(x))) - sin(cos(0)) * x * x
# Методом численного дифференцирования: -12.68559
# Методом автоматического дифференцирования: 6833.28785
#
# Функция для дифференцирования, в точке x = 9:
# sin(7 - x)
# Методом численного дифференцирования: 0.35018
# Методом автоматического дифференцирования: -0.41615
#
# Функция для дифференцирования, в точке x = 5:
# sin(cos(x))
# Методом численного дифференцирования: 0.71369
# Методом автоматического дифференцирования: 0.92060
#
# Функция для дифференцирования, в точке x = 10:
# exp(10 / x * sin(sin(cos(x / sin(5))) + x))
# Методом численного дифференцирования: -1.22274
# Методом автоматического дифференцирования: -1.63854
#
# Функция для дифференцирования, в точке x = 4:
# sin(8 - cos(sin(6)) - 10 - exp(17)) / x * cos(x)
# Методом численного дифференцирования: 0.11578
# Методом автоматического дифференцирования: 0.19392
#
# Функция для дифференцирования, в точке x = 9:
# sin(9) / 17 + exp(12) ** sin(log(10))
# Методом численного дифференцирования: 0.00000
# Методом автоматического дифференцирования: 0.00000
#
# Функция для дифференцирования, в точке x = 7:
# cos(cos(18)) * sin(13) - x - exp(18) - exp(7)
# Методом численного дифференцирования: -1.00000
# Методом автоматического дифференцирования: -1.00000
#
# Функция для дифференцирования, в точке x = 10:
# cos(x) / cos(exp(x + 20))
# Методом численного дифференцирования: 1.01827
# Методом автоматического дифференцирования: 674392682217.34875
#
# Функция для дифференцирования, в точке x = 7:
# 8 / x ** log(sin(sin(3 * x)) ** x ** 1)
# Методом численного дифференцирования: -27.44110
# Методом автоматического дифференцирования: 9747.68846
#
# Функция для дифференцирования, в точке x = 7:
# cos(cos(x))
# Методом численного дифференцирования: 0.20803
# Методом автоматического дифференцирования: 0.44970
#
# Функция для дифференцирования, в точке x = 10:
# log(x) * sin(log(x) ** 13)
# Методом численного дифференцирования: 0.72021
# Методом автоматического дифференцирования: 66441.36171
#
# Функция для дифференцирования, в точке x = 4:
# cos(x - exp(x) - sin(x))
# Методом численного дифференцирования: -0.20849
# Методом автоматического дифференцирования: 21.78839
#
# Функция для дифференцирования, в точке x = 10:
# 8 * 10 * sin(x - sin(x) + x)
# Методом численного дифференцирования: 4.25544
# Методом автоматического дифференцирования: -28.01684
#
# Функция для дифференцирования, в точке x = 10:
# log(x) * 19 / x / x
# Методом численного дифференцирования: -0.06943
# Методом автоматического дифференцирования: -0.06850
#
# Функция для дифференцирования, в точке x = 2:
# exp(log(20) - sin(sin(5 + x)))
# Методом численного дифференцирования: -8.83994
# Методом автоматического дифференцирования: -6.48250
#
# Функция для дифференцирования, в точке x = 9:
# log(x) - cos(x / x)
# Методом численного дифференцирования: 0.11157
# Методом автоматического дифференцирования: 0.11111
#
# Функция для дифференцирования, в точке x = 6:
# sin(8) + cos(5 ** x / 9 + 3 / cos(x))
# Методом численного дифференцирования: -0.27701
# Методом автоматического дифференцирования: 2610.21750
#
# Функция для дифференцирования, в точке x = 8:
# sin(sin(sin(x * exp(3) / sin(13 / 10) - 12)) / 12)
# Методом численного дифференцирования: -0.04616
# Методом автоматического дифференцирования: -0.87586
#
# Функция для дифференцирования, в точке x = 8:
# sin(x - 18)
# Методом численного дифференцирования: -0.70605
# Методом автоматического дифференцирования: -0.83907
#
# Функция для дифференцирования, в точке x = 10:
# cos(x) / sin(cos(13)) - cos(13) / sin(4 - cos(x))
# Методом численного дифференцирования: 0.71998
# Методом автоматического дифференцирования: 0.75382
#
# Функция для дифференцирования, в точке x = 9:
# x + sin(7) * exp(x) + sin(x) - x
# Методом численного дифференцирования: 6255.55501
# Методом автоматического дифференцирования: 5322.70642
#
# Функция для дифференцирования, в точке x = 8:
# sin(sin(x) ** 5)
# Методом численного дифференцирования: -0.05510
# Методом автоматического дифференцирования: -0.40663
#
# Функция для дифференцирования, в точке x = 6:
# sin(cos(cos(2 * x)))
# Методом численного дифференцирования: 0.10843
# Методом автоматического дифференцирования: -0.63121
#
# Функция для дифференцирования, в точке x = 3:
# sin(20 ** x)
# Методом численного дифференцирования: -0.05813
# Методом автоматического дифференцирования: 1573.24182
#
# Функция для дифференцирования, в точке x = 8:
# sin(x * x)
# Методом численного дифференцирования: 0.16193
# Методом автоматического дифференцирования: 6.26972
#
# Функция для дифференцирования, в точке x = 5:
# sin(2) - 6 ** sin(exp(10)) * exp(cos(x - exp(cos(cos(x))) ** x / sin(cos(20)) - sin(11))) ** 8
# Методом численного дифференцирования: 2.15861
# Методом автоматического дифференцирования: 1559.89382
#
# Функция для дифференцирования, в точке x = 6:
# 18 / cos(cos(sin(x))) - sin(16 / log(sin(log(11 * exp(sin(sin(16 / x / 14 - cos(5) - x * 11 ** x + sin(x))))))) / x)
# Методом численного дифференцирования: 1.48188
# Методом автоматического дифференцирования: -17509519484974.41992

# %% [markdown]
# ## Задание 1.5 (7 баллов)
#
# Реализуйте поддержку функций нескольких аргументов. Например
#
# ```python
# def f(x: float, y: float, z: float) -> float:
#     return x * y + z - 5 * y
#
#
# f_diff = diff(f)
#
# f_diff(10, 10, 10) # = [10, 5, 1]
# ```

# %%
from dataclasses import dataclass
from typing import Union, Callable
from numbers import Number

from numpy import real

@dataclass
class Dual:
    real: float
    dual: dict

    def __add__(self, other: Union["Dual", Number]) -> "Dual":
         match other:
            case Dual():
                real = self.real + other.real
                dual = {}
                for key in self.dual:
                    dual[key] = self.dual[key]
                for key in other.dual:
                    if key in dual:
                        dual[key] += other.dual[key]
                    else:
                        dual[key] = other.dual[key]
                return Dual(real, dual)
            case Number():
                return Dual(float(other) + self.real, self.dual)

    def __mul__(self, other: Union["Dual", Number]) -> "Dual":
         match other:
            case Dual():
                real = self.real * other.real
                dual = {}
                for key in self.dual:
                    dual[key] = self.dual[key] * other.real
                for key in other.dual:
                    if key in dual:
                        dual[key] += other.dual[key] * self.real
                    else:
                        dual[key] = other.dual[key] * self.real
                return Dual(real, dual)
            case Number():
                dual = {}
                for key in self.dual:
                    dual[key] = self.dual[key] * other
                return Dual(self.real * other, dual)
    
    def __neg__(self) -> "Dual":
        dual = {}
        for key in self.dual:
            dual[key] = self.dual[key] * (-1)
        return Dual(-self.real, self.dual)
    
    def __pos__(self) -> "Dual":
        dual = {}
        for key in self.dual:
            dual[key] = self.dual[key] * (+1)
        return Dual(self.real, +self.dual)
    
    def __abs__(self) -> "Dual":
        dual = {}
        for key in self.dual:
            dual[key] = abs(self.dual[key])
        return Dual(abs(self.real), self.dual)

    def __sub__(self, other: Union["Dual", Number]) -> "Dual":
        match other:
            case Dual():
                real = self.real - other.real
                dual = {}
                for key in self.dual:
                    dual[key] = self.dual[key]
                for key in other.dual:
                    if key in dual:
                        dual[key] -= other.dual[key]
                    else:
                        dual[key] = -other.dual[key]
                return Dual(real, dual)
            case Number():
                return Dual(self.real - float(other), self.dual)
    
    def div_neg(self, other):
        dual = {}
        for key in other.dual:
            dual[key] = other.dual[key]*(-1)
        return Dual(other.real, dual)

    def __truediv__(self,other: Union["Dual", Number]) -> "Dual":
        if other.real == 0:
            raise ZeroDivisionError("Attempting to divide by a zero")

        match other:
            case Dual():
                new_arg = self.div_neg(other)
                num = Dual(self.real, self.dual)
                num_modified = num*new_arg
                dual = {}
                for key in num_modified.dual:
                    dual[key] = num_modified.dual[key] / (other.real*other.real)
                return Dual(num_modified.real / (other.real*other.real), dual)
            case Number():
                dual = {}
                for key in self.dual:
                    dual[key] = self.dual[key] / other
                return Dual(self.real / other, dual)

    def __rtruediv__(self,other: Union["Dual", Number]) -> "Dual":
        if self.real == 0:
            raise ZeroDivisionError("Attempting to divide by a zero")

        den = Dual(self.real, self.dual)
        new_arg = self.div_neg(den)
        num_modified = other*new_arg
        dual = {}
        for key in num_modified.dual:
            dual[key] = num_modified.dual[key] / (self.real*self.real)
        return Dual(num_modified.real / (self.real*self.real), dual)

    def __pow__(self, power: Union["Dual", Number]) -> "Dual": 
        real = self.real
        dual = {}
        for key in self.dual:
            dual[key] = power * self.dual[key] * (real ** (power - 1))

        return Dual(real ** power, dual)
    
    def __rpow__(self, other: Union["Dual", Number]) -> "Dual": 
        if other.real == 0:
            raise Exception("log(0) is not defined")
        real = other ** self.real
        dual = {}
        for key in self.dual:
            dual[key] = (other ** self.real) * (self.dual[key] * log(other))
        
        return Dual(real, dual)

    __radd__ = __add__
    __rmul__ = __mul__

    def __str__(self):
        s = 'f = ' + str(round(self.real,6)) + '\n'
        for key in self.dual:
            s += 'f' + key + ' = ' + str(round(self.dual[key],6)) + '\n'
        return s

def diff(func: Callable[[float], float]) -> Callable[[float], float]:
    return lambda x, y, z: func(Dual(x, {'x': 1}), Dual(y, {'y': 1}), Dual(z, {'z': 1})).dual

# %%
def sin_d(dual_num) -> "Dual":
    dual = {}
    real = sin(dual_num.real)
    for key in dual_num.dual:
        dual[key] = cos(dual_num.real) * dual_num.dual[key]
    return Dual(real, dual)

def cos_d(dual_num) -> "Dual":
    dual = {}
    real = cos(dual_num.real)
    for key in dual_num.dual:
        dual[key] = -sin(dual_num.real) * dual_num.dual[key] 
    return Dual(real, dual)

def exp_d(dual_num) -> "Dual":
    dual = {}
    real = exp(dual_num.real)
    for key in dual_num.dual:
        dual[key] = real * dual_num.dual[key]
    return Dual(real, dual)

def log_d(dual_num) -> "Dual":
    if dual_num.real == 0:
        raise AssertionError("log(0) is not defined")
    
    dual = {}
    real = log(dual_num.real)
    for key in dual_num.dual:
        dual[key] = dual_num.dual[key] / dual_num.real
    return Dual(real, dual)

# %%
def f(x: float, y: float, z: float) -> float:
    return x * y + z - 5 * y  

f_diff = diff(f)
f_diff(10, 10, 10)
# Out:
# {'x': 10, 'y': 5, 'z': 1}

# %% [markdown]
# Проверим на нескольких функциях:
#
# $$f(x,y) = 6x^3 + 3x^2y^2 - 2y^3$$
# $$f_x = \frac {\partial f} {\partial x} = 6x(3x + y^2)$$
# $$f_y = \frac {\partial f} {\partial y} = 6y(x^2 -2)$$
# В точке: x = 2, y = 3
#
# $$f = 102$$
# $$f_x = 180$$
# $$f_y = 18$$

# %%
x = Dual(real=2, dual={'x': 1})
y = Dual(real=3, dual={'y': 1})

f = 6 * (x**3) + 3 * (x**2)*(y**2) - 2 * (y**3)
print(f)
# Out:
# f = 102
# fx = 180
# fy = 18

# %% [markdown]
# $$f(x,y) = \frac {36x} {x + y^2}$$
# $$f_x = \frac {\partial f} {\partial x} = \frac{36y^2}{(x+y^2)^2}$$
# $$f_y = \frac {\partial f} {\partial y} = -\frac{72xy}{(x+y^2)^2}$$
#
# В точке: x = 2, y = 1
#
# $$f = 24$$
# $$f_x = 4$$
# $$f_y = -16$$

# %%
def f(x: float, y: float, z: float) -> float:
    return 36*x / (x + y**2)

f_diff = diff(f)
f_diff(2, 1, 0)
# Out:
# {'x': 4.0, 'y': -16.0}

# %% [markdown]
# $$f(x,y) = \frac {\sin(y)} {cos(x) + x**2}$$
# $$f_x = \frac {\partial f} {\partial x} = \frac{(\sin(x)-2x)\sin(y)}{(x^2+\cos(x))^2}$$
# $$f_y = \frac {\partial f} {\partial y} = \frac{\cos(y)}{cos(x) + x^2}$$
#
# В точке: $$x = \pi, y = \pi, z = 1$$
#
# $$f = 0$$
# $$f_x = 0$$
# $$f_y = -0.112745$$

# %%
x = Dual(pi, {'x': 1})
y = Dual(pi, {'y': 1})

f = (sin_d(y) / (cos_d(x) + x**2))
print(f)
# Out:
# f = 0.0
# fy = -0.112745
# fx = -0.0
